# %%
import numpy as np

# %%
array = np.array([1, 2])
print(np.sum(array))
array.sum()
# Out:
# 3
# np.int64(3)

# %%
array = np.array([0, 1, 2, 3, 4], dtype=bool)
array
# Out:
# array([False,  True,  True,  True,  True])
